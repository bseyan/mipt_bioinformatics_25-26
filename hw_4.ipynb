# %% [markdown]
# возьмем неочевидный белок инсулин(гормон, регулирующий уровень глюкозы в крови)
# представленные последовательности принадлежат:
# - Человеку (Homo sapiens)
# - Большой панде (Ailuropoda melanoleuca)
# - Свинье (Sus scrofa)
# - Североамериканской амии (Amia calva)

# %%
pip install Bio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.0/281.0 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 68.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 3.6 MB/s eta 0:00:00
# ...

# %%
from Bio import Phylo
import matplotlib.pyplot as plt

# %%
newick_file = "muscle-I20250318-111538-0296-63263864-p1m.phylotree"
tree = Phylo.read(newick_file, "newick")

Phylo.draw_ascii(tree)
# Out:
#       ____________________ tr|A0A7N5JXI9|A0A7N5JXI9_AILME
#   ___|
#  |   |__________________________________________ sp|P29335|INS_AMICA
# _|
#  |____________ sp|P01308|INS_HUMAN
#  |
#  |__________ sp|P01315|INS_PIG

# %%
Phylo.draw(tree)
plt.show()
